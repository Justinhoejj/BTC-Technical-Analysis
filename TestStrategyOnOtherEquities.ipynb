# %% [markdown]
# This program tests the performance of each strategy on various price charts over a time period of 1 year.

# %%
from technicalIndicatorUtils import analyse, execute_MACD, execute_OBV_EMA, execute_MACD_OBV, plot_close_price, execute_buy_hold
import pandas as pd
import numpy as np

# %%
def report(filepath):
    df = analyse(filepath).tail(300)
    plot_close_price(df)
    print("\n===== BASELINE BUY AND HOLD STRATEGY ========")
    print(execute_buy_hold(df))
    print("\n===== MACD STRATEGY =========================")
    print(execute_MACD(df))
    print("\n===== MACD STRATEGY WITH STOP LOSS ===========")
    print(execute_MACD(df, use_stop_loss=True))
    print("\n===== OBV STRATEGY ===========================")
    print(execute_OBV_EMA(df))
    print("\n===== OBV STRATEGY WITH STOP LOSS ============")
    print(execute_OBV_EMA(df, use_stop_loss=True))
    print("\n===== OBV & MACD STRATEGY ====================")
    print(execute_MACD_OBV(df))
    print("\n===== OBV & MACD STRATEGY WITH STOP LOSS =====")
    print(execute_MACD_OBV(df, use_stop_loss=True))

# %% [markdown]
# <h1>Bitcoin (Uptrend with multiple All Time High)</h1>

# %%
report('testDataset/BTC-USD.csv')
# Out:
# ===== BASELINE BUY AND HOLD STRATEGY ========
# -14.552
#
# ===== MACD STRATEGY =========================
# Wins:3, max gain:9.139
# Losses:8, max loss: -42.297
# Cumulative Percentage Gains: -7.581%
# Sum of independent percentage gains: 4.934%
#
# ===== MACD STRATEGY WITH STOP LOSS ===========
# Wins:3, max gain:16.382
# Losses:8, max loss: -35.053
# Cumulative Percentage Gains: 0.284%
# Sum of independent percentage gains: 12.178%
#
# ===== OBV STRATEGY ===========================
# Wins:8, max gain:49.883
# Losses:16, max loss: -12.22
# Cumulative Percentage Gains: 43.974%
# Sum of independent percentage gains: 46.878%
#
# ===== OBV STRATEGY WITH STOP LOSS ============
# Wins:8, max gain:49.883
# Losses:16, max loss: -12.22
# Cumulative Percentage Gains: 43.974%
# Sum of independent percentage gains: 46.878%
#
# ===== OBV & MACD STRATEGY ====================
# Wins:5, max gain:30.066
# Losses:5, max loss: -43.372
# Cumulative Percentage Gains: 8.31%
# Sum of independent percentage gains: 30.066%
#
# ===== OBV & MACD STRATEGY WITH STOP LOSS =====
# Wins:5, max gain:15.652
# Losses:10, max loss: -45.428
# Cumulative Percentage Gains: -12.055%
# Sum of independent percentage gains: 1.461%

# %% [markdown]
# <h1>Ethereum (Uptrend with multiple All Time High)</h1>

# %%
report('testDataset/ETH-USD.csv')
# Out:
# ===== BASELINE BUY AND HOLD STRATEGY ========
# 117.421
#
# ===== MACD STRATEGY =========================
# Wins:4, max gain:99.625
# Losses:7, max loss: -1.204
# Cumulative Percentage Gains: 73.277%
# Sum of independent percentage gains: 81.374%
#
# ===== MACD STRATEGY WITH STOP LOSS ===========
# Wins:4, max gain:97.775
# Losses:7, max loss: -1.204
# Cumulative Percentage Gains: 73.93%
# Sum of independent percentage gains: 81.708%
#
# ===== OBV STRATEGY ===========================
# Wins:9, max gain:89.086
# Losses:14, max loss: -9.275
# Cumulative Percentage Gains: 81.729%
# Sum of independent percentage gains: 89.086%
#
# ===== OBV STRATEGY WITH STOP LOSS ============
# Wins:9, max gain:89.086
# Losses:14, max loss: -9.275
# Cumulative Percentage Gains: 81.729%
# Sum of independent percentage gains: 89.086%
#
# ===== OBV & MACD STRATEGY ====================
# Wins:6, max gain:144.959
# Losses:4, max loss: 11.439
# Cumulative Percentage Gains: 182.033%
# Sum of independent percentage gains: 137.636%
#
# ===== OBV & MACD STRATEGY WITH STOP LOSS =====
# Wins:6, max gain:76.42
# Losses:9, max loss: -11.1
# Cumulative Percentage Gains: 31.292%
# Sum of independent percentage gains: 64.009%

# %% [markdown]
# <h1>XRP (Uptrend without new all time highs)</h1>

# %%
report('testDataset/XRP-USD.csv')
# Out:
# ===== BASELINE BUY AND HOLD STRATEGY ========
# 40.955
#
# ===== MACD STRATEGY =========================
# Wins:4, max gain:195.782
# Losses:6, max loss: 96.246
# Cumulative Percentage Gains: 75.861%
# Sum of independent percentage gains: 181.473%
#
# ===== MACD STRATEGY WITH STOP LOSS ===========
# Wins:4, max gain:230.334
# Losses:6, max loss: 130.798
# Cumulative Percentage Gains: 180.783%
# Sum of independent percentage gains: 216.025%
#
# ===== OBV STRATEGY ===========================
# Wins:4, max gain:155.649
# Losses:20, max loss: -14.882
# Cumulative Percentage Gains: 73.187%
# Sum of independent percentage gains: 149.632%
#
# ===== OBV STRATEGY WITH STOP LOSS ============
# Wins:4, max gain:155.649
# Losses:20, max loss: -14.882
# Cumulative Percentage Gains: 73.187%
# Sum of independent percentage gains: 149.632%
#
# ===== OBV & MACD STRATEGY ====================
# Wins:4, max gain:203.536
# Losses:3, max loss: 112.193
# Cumulative Percentage Gains: 110.887%
# Sum of independent percentage gains: 203.536%
#
# ===== OBV & MACD STRATEGY WITH STOP LOSS =====
# Wins:5, max gain:220.894
# Losses:6, max loss: 134.206
# Cumulative Percentage Gains: 157.88%
# Sum of independent percentage gains: 201.858%

# %% [markdown]
# <h1>Litecoin (Sideway with fall from all time high)</h1>

# %%
report('testDataset/LTC-USD.csv')
# Out:
# ===== BASELINE BUY AND HOLD STRATEGY ========
# -29.673
#
# ===== MACD STRATEGY =========================
# Wins:5, max gain:32.808
# Losses:5, max loss: -15.19
# Cumulative Percentage Gains: -9.197%
# Sum of independent percentage gains: 10.744%
#
# ===== MACD STRATEGY WITH STOP LOSS ===========
# Wins:5, max gain:44.383
# Losses:5, max loss: -1.523
# Cumulative Percentage Gains: 17.618%
# Sum of independent percentage gains: 29.86%
#
# ===== OBV STRATEGY ===========================
# Wins:8, max gain:65.975
# Losses:14, max loss: -1.365
# Cumulative Percentage Gains: -9.561%
# Sum of independent percentage gains: 21.102%
#
# ===== OBV STRATEGY WITH STOP LOSS ============
# Wins:8, max gain:65.975
# Losses:14, max loss: -1.365
# Cumulative Percentage Gains: -9.561%
# Sum of independent percentage gains: 21.102%
#
# ===== OBV & MACD STRATEGY ====================
# Wins:4, max gain:53.922
# Losses:4, max loss: -13.032
# Cumulative Percentage Gains: -21.006%
# Sum of independent percentage gains: 16.337%
#
# ===== OBV & MACD STRATEGY WITH STOP LOSS =====
# Wins:5, max gain:53.922
# Losses:6, max loss: -1.546
# Cumulative Percentage Gains: -23.161%
# Sum of independent percentage gains: -1.546%

# %% [markdown]
# <h1>EOS (Sideways with fall from all time high)</h1>

# %%
report('testDataset/EOS-USD.csv')
# Out:
# ===== BASELINE BUY AND HOLD STRATEGY ========
# -31.863
#
# ===== MACD STRATEGY =========================
# Wins:4, max gain:75.975
# Losses:9, max loss: -13.218
# Cumulative Percentage Gains: -7.777%
# Sum of independent percentage gains: 22.756%
#
# ===== MACD STRATEGY WITH STOP LOSS ===========
# Wins:4, max gain:83.318
# Losses:9, max loss: -7.362
# Cumulative Percentage Gains: 2.934%
# Sum of independent percentage gains: 32.394%
#
# ===== OBV STRATEGY ===========================
# Wins:8, max gain:38.437
# Losses:23, max loss: -107.569
# Cumulative Percentage Gains: -77.723%
# Sum of independent percentage gains: -107.569%
#
# ===== OBV STRATEGY WITH STOP LOSS ============
# Wins:8, max gain:38.437
# Losses:23, max loss: -107.569
# Cumulative Percentage Gains: -77.723%
# Sum of independent percentage gains: -107.569%
#
# ===== OBV & MACD STRATEGY ====================
# Wins:6, max gain:86.908
# Losses:5, max loss: -4.58
# Cumulative Percentage Gains: 4.099%
# Sum of independent percentage gains: 41.36%
#
# ===== OBV & MACD STRATEGY WITH STOP LOSS =====
# Wins:6, max gain:50.023
# Losses:11, max loss: -67.942
# Cumulative Percentage Gains: -65.13%
# Sum of independent percentage gains: -67.942%

# %% [markdown]
# <h1>Link (Sideway with fall from all time high)</h1>

# %%
report('testDataset/LINK-USD.csv')
# Out:
# ===== BASELINE BUY AND HOLD STRATEGY ========
# -40.897
#
# ===== MACD STRATEGY =========================
# Wins:3, max gain:13.929
# Losses:9, max loss: -67.761
# Cumulative Percentage Gains: -31.196%
# Sum of independent percentage gains: -9.468%
#
# ===== MACD STRATEGY WITH STOP LOSS ===========
# Wins:3, max gain:13.929
# Losses:9, max loss: -55.597
# Cumulative Percentage Gains: -20.34%
# Sum of independent percentage gains: 2.697%
#
# ===== OBV STRATEGY ===========================
# Wins:4, max gain:42.93
# Losses:18, max loss: -94.411
# Cumulative Percentage Gains: -70.969%
# Sum of independent percentage gains: -81.927%
#
# ===== OBV STRATEGY WITH STOP LOSS ============
# Wins:4, max gain:42.93
# Losses:18, max loss: -94.411
# Cumulative Percentage Gains: -70.969%
# Sum of independent percentage gains: -81.927%
#
# ===== OBV & MACD STRATEGY ====================
# Wins:4, max gain:1.334
# Losses:5, max loss: -100.377
# Cumulative Percentage Gains: -40.617%
# Sum of independent percentage gains: -15.589%
#
# ===== OBV & MACD STRATEGY WITH STOP LOSS =====
# Wins:4, max gain:1.334
# Losses:12, max loss: -153.621
# Cumulative Percentage Gains: -81.802%
# Sum of independent percentage gains: -126.133%

# %% [markdown]
# <h1>Doge (Downtrend with lower highs)</h1>

# %%
report('testDataset/DOGE-USD.csv')
# Out:
# ===== BASELINE BUY AND HOLD STRATEGY ========
# 189.912
#
# ===== MACD STRATEGY =========================
# Wins:4, max gain:383.815
# Losses:3, max loss: -7.371
# Cumulative Percentage Gains: 474.523%
# Sum of independent percentage gains: 383.815%
#
# ===== MACD STRATEGY WITH STOP LOSS ===========
# Wins:3, max gain:42.787
# Losses:4, max loss: -26.96
# Cumulative Percentage Gains: 26.963%
# Sum of independent percentage gains: 42.787%
#
# ===== OBV STRATEGY ===========================
# Wins:4, max gain:680.543
# Losses:20, max loss: -3.312
# Cumulative Percentage Gains: 73.401%
# Sum of independent percentage gains: 550.483%
#
# ===== OBV STRATEGY WITH STOP LOSS ============
# Wins:4, max gain:680.543
# Losses:20, max loss: -3.312
# Cumulative Percentage Gains: 73.401%
# Sum of independent percentage gains: 550.483%
#
# ===== OBV & MACD STRATEGY ====================
# Wins:4, max gain:351.848
# Losses:2, max loss: 13.675
# Cumulative Percentage Gains: 306.915%
# Sum of independent percentage gains: 351.848%
#
# ===== OBV & MACD STRATEGY WITH STOP LOSS =====
# Wins:4, max gain:378.227
# Losses:7, max loss: 6.702
# Cumulative Percentage Gains: 188.402%
# Sum of independent percentage gains: 345.064%
